# %%
import selenium

# %%
from selenium import webdriver

browser = webdriver.Firefox()
browser.get('https://giftpass.sodexomerchant.com/merchant')

# %%
content = browser.find_element_by_class_name('content')
container = content.find_element_by_class_name('container')
print(container)
# Out:
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="1b98e882-2a7c-9247-b534-43f242a49b52", element="8a59ba2d-d94b-ea4a-a638-930679421b87")>

# %%
header3 = container.find_element_by_tag_name('h3')
category = header3.text
print(type(category))
# Out:
# <class 'str'>

# %%
getLink_merch_name = container.find_element_by_tag_name("a")
link_merch_name = getLink_merch_name.get_attribute('href')
print(link_merch_name)
# Out:
# https://giftpass.sodexomerchant.com/getMap?id=930#map_section

# %%
list_a = getLink_merch_name.find_elements_by_xpath('//a[@href]')

for a in list_a:
    href = a.get_attribute('href')
    print(href)

get_href = container.find_element_by_tag_name("a")
#     link_merch_name = get_href.get_attribute('href')
#     print(link_merch_name)
# Out:
# http://www.sodexoindonesia.co.id/
# https://www.facebook.com/SodexoIndoPage
# https://twitter.com/sodexoindonesia
# mailto:cs.svc.id@sodexo.com
# tel:+6281519540325
# tel:+6221780 1859
# https://giftpass.sodexomerchant.com/
# http://sodexomerchant.com/
# https://giftpass.sodexomerchant.com/merchant
# https://giftpass.sodexomerchant.com/pass-voucher
# https://beli.sodexovoucher.com/
# https://giftpass.sodexomerchant.com/faqs
# https://giftpass.sodexomerchant.com/getMap?id=930#map_section
# https://giftpass.sodexomerchant.com/getMap?id=931#map_section
# https://giftpass.sodexomerchant.com/getMap?id=717#map_section
# https://giftpass.sodexomerchant.com/getMap?id=771#map_section
# https://giftpass.sodexomerchant.com/getMap?id=713#map_section
# https://giftpass.sodexomerchant.com/getMap?id=712#map_section
# https://giftpass.sodexomerchant.com/getMap?id=73#map_section
# https://giftpass.sodexomerchant.com/getMap?id=430#map_section
# https://giftpass.sodexomerchant.com/getMap?id=957#map_section
# https://giftpass.sodexomerchant.com/getMap?id=956#map_section
# https://giftpass.sodexomerchant.com/getMap?id=955#map_section
# https://giftpass.sodexomerchant.com/getMap?id=954#map_section
# https://giftpass.sodexomerchant.com/getMap?id=936#map_section
# https://giftpass.sodexomerchant.com/getMap?id=934#map_section
# https://giftpass.sodexomerchant.com/getMap?id=933#map_section
# https://giftpass.sodexomerchant.com/getMap?id=932#map_section
# https://giftpass.sodexomerchant.com/getMap?id=926#map_section
# https://giftpass.sodexomerchant.com/getMap?id=925#map_section
# https://giftpass.sodexomerchant.com/getMap?id=924#map_section
# https://giftpass.sodexomerchant.com/getMap?id=922#map_section
# https://giftpass.sodexomerchant.com/getMap?id=921#map_section
# https://giftpass.sodexomerchant.com/getMap?id=920#map_section
# https://giftpass.sodexomerchant.com/getMap?id=917#map_section
# https://giftpass.sodexomerchant.com/getMap?id=916#map_section
# https://giftpass.sodexomerchant.com/getMap?id=914#map_section
# https://giftpass.sodexomerchant.com/getMap?id=913#map_section
# https://giftpass.sodexomerchant.com/getMap?id=911#map_section
# https://giftpass.sodexomerchant.com/getMap?id=910#map_section
# https://giftpass.sodexomerchant.com/getMap?id=909#map_section
# https://giftpass.sodexomerchant.com/getMap?id=908#map_section
# https://giftpass.sodexomerchant.com/getMap?id=905#map_section
# https://giftpass.sodexomerchant.com/getMap?id=895#map_section
# https://giftpass.sodexomerchant.com/getMap?id=889#map_section
# https://giftpass.sodexomerchant.com/getMap?id=888#map_section
# https://giftpass.sodexomerchant.com/getMap?id=885#map_section
# https://giftpass.sodexomerchant.com/getMap?id=884#map_section
# https://giftpass.sodexomerchant.com/getMap?id=848#map_section
# https://giftpass.sodexomerchant.com/getMap?id=847#map_section
# https://giftpass.sodexomerchant.com/getMap?id=846#map_section
# https://giftpass.sodexomerchant.com/getMap?id=845#map_section
# https://giftpass.sodexomerchant.com/getMap?id=844#map_section
# https://giftpass.sodexomerchant.com/getMap?id=843#map_section
# https://giftpass.sodexomerchant.com/getMap?id=840#map_section
# https://giftpass.sodexomerchant.com/getMap?id=839#map_section
# https://giftpass.sodexomerchant.com/getMap?id=838#map_section
# https://giftpass.sodexomerchant.com/getMap?id=837#map_section
# https://giftpass.sodexomerchant.com/getMap?id=836#map_section
# https://giftpass.sodexomerchant.com/getMap?id=835#map_section
# https://giftpass.sodexomerchant.com/getMap?id=834#map_section
# https://giftpass.sodexomerchant.com/getMap?id=833#map_section
# https://giftpass.sodexomerchant.com/getMap?id=832#map_section
# https://giftpass.sodexomerchant.com/getMap?id=831#map_section
# https://giftpass.sodexomerchant.com/getMap?id=830#map_section
# https://giftpass.sodexomerchant.com/getMap?id=829#map_section
# https://giftpass.sodexomerchant.com/getMap?id=824#map_section
# https://giftpass.sodexomerchant.com/getMap?id=810#map_section
# https://giftpass.sodexomerchant.com/getMap?id=809#map_section
# https://giftpass.sodexomerchant.com/getMap?id=808#map_section
# https://giftpass.sodexomerchant.com/getMap?id=807#map_section
# https://giftpass.sodexomerchant.com/getMap?id=806#map_section
# https://giftpass.sodexomerchant.com/getMap?id=801#map_section
# https://giftpass.sodexomerchant.com/getMap?id=800#map_section
# https://giftpass.sodexomerchant.com/getMap?id=799#map_section
# https://giftpass.sodexomerchant.com/getMap?id=798#map_section
# https://giftpass.sodexomerchant.com/getMap?id=797#map_section
# https://giftpass.sodexomerchant.com/getMap?id=796#map_section
# https://giftpass.sodexomerchant.com/getMap?id=795#map_section
# https://giftpass.sodexomerchant.com/getMap?id=794#map_section
# https://giftpass.sodexomerchant.com/getMap?id=793#map_section
# https://giftpass.sodexomerchant.com/getMap?id=786#map_section
# https://giftpass.sodexomerchant.com/getMap?id=783#map_section
# https://giftpass.sodexomerchant.com/getMap?id=782#map_section
# https://giftpass.sodexomerchant.com/getMap?id=781#map_section
# https://giftpass.sodexomerchant.com/getMap?id=780#map_section
# https://giftpass.sodexomerchant.com/getMap?id=779#map_section
# https://giftpass.sodexomerchant.com/getMap?id=778#map_section
# https://giftpass.sodexomerchant.com/getMap?id=777#map_section
# https://giftpass.sodexomerchant.com/getMap?id=776#map_section
# https://giftpass.sodexomerchant.com/getMap?id=773#map_section
# https://giftpass.sodexomerchant.com/getMap?id=772#map_section
# https://giftpass.sodexomerchant.com/getMap?id=770#map_section
# https://giftpass.sodexomerchant.com/getMap?id=769#map_section
# https://giftpass.sodexomerchant.com/getMap?id=768#map_section
# https://giftpass.sodexomerchant.com/getMap?id=767#map_section
# https://giftpass.sodexomerchant.com/getMap?id=766#map_section
# https://giftpass.sodexomerchant.com/getMap?id=765#map_section
# https://giftpass.sodexomerchant.com/getMap?id=764#map_section
# https://giftpass.sodexomerchant.com/getMap?id=763#map_section
# https://giftpass.sodexomerchant.com/getMap?id=761#map_section
# https://giftpass.sodexomerchant.com/getMap?id=760#map_section
# https://giftpass.sodexomerchant.com/getMap?id=759#map_section
# https://giftpass.sodexomerchant.com/getMap?id=758#map_section
# https://giftpass.sodexomerchant.com/getMap?id=757#map_section
# https://giftpass.sodexomerchant.com/getMap?id=756#map_section
# https://giftpass.sodexomerchant.com/getMap?id=755#map_section
# https://giftpass.sodexomerchant.com/getMap?id=752#map_section
# https://giftpass.sodexomerchant.com/getMap?id=751#map_section
# https://giftpass.sodexomerchant.com/getMap?id=749#map_section
# https://giftpass.sodexomerchant.com/getMap?id=748#map_section
# https://giftpass.sodexomerchant.com/getMap?id=747#map_section
# https://giftpass.sodexomerchant.com/getMap?id=745#map_section
# https://giftpass.sodexomerchant.com/getMap?id=742#map_section
# https://giftpass.sodexomerchant.com/getMap?id=740#map_section
# https://giftpass.sodexomerchant.com/getMap?id=737#map_section
# https://giftpass.sodexomerchant.com/getMap?id=736#map_section
# https://giftpass.sodexomerchant.com/getMap?id=733#map_section
# https://giftpass.sodexomerchant.com/getMap?id=732#map_section
# https://giftpass.sodexomerchant.com/getMap?id=729#map_section
# https://giftpass.sodexomerchant.com/getMap?id=728#map_section
# https://giftpass.sodexomerchant.com/getMap?id=727#map_section
# https://giftpass.sodexomerchant.com/getMap?id=726#map_section
# https://giftpass.sodexomerchant.com/getMap?id=725#map_section
# https://giftpass.sodexomerchant.com/getMap?id=724#map_section
# https://giftpass.sodexomerchant.com/getMap?id=723#map_section
# https://giftpass.sodexomerchant.com/getMap?id=722#map_section
# https://giftpass.sodexomerchant.com/getMap?id=721#map_section
# https://giftpass.sodexomerchant.com/getMap?id=718#map_section
# https://giftpass.sodexomerchant.com/getMap?id=716#map_section
# https://giftpass.sodexomerchant.com/getMap?id=715#map_section
# https://giftpass.sodexomerchant.com/getMap?id=714#map_section
# https://giftpass.sodexomerchant.com/getMap?id=710#map_section
# https://giftpass.sodexomerchant.com/getMap?id=709#map_section
# https://giftpass.sodexomerchant.com/getMap?id=707#map_section
# https://giftpass.sodexomerchant.com/getMap?id=706#map_section
# https://giftpass.sodexomerchant.com/getMap?id=704#map_section
# https://giftpass.sodexomerchant.com/getMap?id=703#map_section
# https://giftpass.sodexomerchant.com/getMap?id=699#map_section
# https://giftpass.sodexomerchant.com/getMap?id=696#map_section
# https://giftpass.sodexomerchant.com/getMap?id=685#map_section
# https://giftpass.sodexomerchant.com/getMap?id=684#map_section
# https://giftpass.sodexomerchant.com/getMap?id=682#map_section
# https://giftpass.sodexomerchant.com/getMap?id=681#map_section
# https://giftpass.sodexomerchant.com/getMap?id=680#map_section
# https://giftpass.sodexomerchant.com/getMap?id=679#map_section
# https://giftpass.sodexomerchant.com/getMap?id=678#map_section
# https://giftpass.sodexomerchant.com/getMap?id=677#map_section
# https://giftpass.sodexomerchant.com/getMap?id=676#map_section
# https://giftpass.sodexomerchant.com/getMap?id=675#map_section
# https://giftpass.sodexomerchant.com/getMap?id=674#map_section
# https://giftpass.sodexomerchant.com/getMap?id=672#map_section
# https://giftpass.sodexomerchant.com/getMap?id=671#map_section
# https://giftpass.sodexomerchant.com/getMap?id=670#map_section
# https://giftpass.sodexomerchant.com/getMap?id=669#map_section
# https://giftpass.sodexomerchant.com/getMap?id=665#map_section
# https://giftpass.sodexomerchant.com/getMap?id=663#map_section
# https://giftpass.sodexomerchant.com/getMap?id=662#map_section
# https://giftpass.sodexomerchant.com/getMap?id=661#map_section
# https://giftpass.sodexomerchant.com/getMap?id=660#map_section
# https://giftpass.sodexomerchant.com/getMap?id=655#map_section
# https://giftpass.sodexomerchant.com/getMap?id=652#map_section
# https://giftpass.sodexomerchant.com/getMap?id=650#map_section
# https://giftpass.sodexomerchant.com/getMap?id=649#map_section
# https://giftpass.sodexomerchant.com/getMap?id=646#map_section
# https://giftpass.sodexomerchant.com/getMap?id=645#map_section
# https://giftpass.sodexomerchant.com/getMap?id=644#map_section
# https://giftpass.sodexomerchant.com/getMap?id=643#map_section
# https://giftpass.sodexomerchant.com/getMap?id=642#map_section
# https://giftpass.sodexomerchant.com/getMap?id=639#map_section
# https://giftpass.sodexomerchant.com/getMap?id=634#map_section
# https://giftpass.sodexomerchant.com/getMap?id=633#map_section
# https://giftpass.sodexomerchant.com/getMap?id=630#map_section
# https://giftpass.sodexomerchant.com/getMap?id=628#map_section
# https://giftpass.sodexomerchant.com/getMap?id=613#map_section
# https://giftpass.sodexomerchant.com/getMap?id=611#map_section
# https://giftpass.sodexomerchant.com/getMap?id=610#map_section
# https://giftpass.sodexomerchant.com/getMap?id=609#map_section
# https://giftpass.sodexomerchant.com/getMap?id=607#map_section
# https://giftpass.sodexomerchant.com/getMap?id=605#map_section
# https://giftpass.sodexomerchant.com/getMap?id=603#map_section
# https://giftpass.sodexomerchant.com/getMap?id=602#map_section
# https://giftpass.sodexomerchant.com/getMap?id=591#map_section
# https://giftpass.sodexomerchant.com/getMap?id=590#map_section
# https://giftpass.sodexomerchant.com/getMap?id=589#map_section
# https://giftpass.sodexomerchant.com/getMap?id=579#map_section
# https://giftpass.sodexomerchant.com/getMap?id=576#map_section
# https://giftpass.sodexomerchant.com/getMap?id=569#map_section
# https://giftpass.sodexomerchant.com/getMap?id=568#map_section
# https://giftpass.sodexomerchant.com/getMap?id=567#map_section
# https://giftpass.sodexomerchant.com/getMap?id=563#map_section
# https://giftpass.sodexomerchant.com/getMap?id=562#map_section
# https://giftpass.sodexomerchant.com/getMap?id=556#map_section
# https://giftpass.sodexomerchant.com/getMap?id=551#map_section
# https://giftpass.sodexomerchant.com/getMap?id=550#map_section
# https://giftpass.sodexomerchant.com/getMap?id=548#map_section
# https://giftpass.sodexomerchant.com/getMap?id=547#map_section
# https://giftpass.sodexomerchant.com/getMap?id=540#map_section
# https://giftpass.sodexomerchant.com/getMap?id=509#map_section
# https://giftpass.sodexomerchant.com/getMap?id=508#map_section
# https://giftpass.sodexomerchant.com/getMap?id=506#map_section
# https://giftpass.sodexomerchant.com/getMap?id=497#map_section
# https://giftpass.sodexomerchant.com/getMap?id=496#map_section
# https://giftpass.sodexomerchant.com/getMap?id=495#map_section
# https://giftpass.sodexomerchant.com/getMap?id=494#map_section
# https://giftpass.sodexomerchant.com/getMap?id=493#map_section
# https://giftpass.sodexomerchant.com/getMap?id=492#map_section
# https://giftpass.sodexomerchant.com/getMap?id=448#map_section
# https://giftpass.sodexomerchant.com/getMap?id=447#map_section
# https://giftpass.sodexomerchant.com/getMap?id=446#map_section
# https://giftpass.sodexomerchant.com/getMap?id=442#map_section
# https://giftpass.sodexomerchant.com/getMap?id=426#map_section
# https://giftpass.sodexomerchant.com/getMap?id=422#map_section
# https://giftpass.sodexomerchant.com/getMap?id=418#map_section
# https://giftpass.sodexomerchant.com/getMap?id=417#map_section
# https://giftpass.sodexomerchant.com/getMap?id=415#map_section
# https://giftpass.sodexomerchant.com/getMap?id=413#map_section
# https://giftpass.sodexomerchant.com/getMap?id=410#map_section
# https://giftpass.sodexomerchant.com/getMap?id=405#map_section
# https://giftpass.sodexomerchant.com/getMap?id=401#map_section
# https://giftpass.sodexomerchant.com/getMap?id=382#map_section
# https://giftpass.sodexomerchant.com/getMap?id=381#map_section
# https://giftpass.sodexomerchant.com/getMap?id=370#map_section
# https://giftpass.sodexomerchant.com/getMap?id=359#map_section
# https://giftpass.sodexomerchant.com/getMap?id=355#map_section
# https://giftpass.sodexomerchant.com/getMap?id=353#map_section
# https://giftpass.sodexomerchant.com/getMap?id=348#map_section
# https://giftpass.sodexomerchant.com/getMap?id=347#map_section
# https://giftpass.sodexomerchant.com/getMap?id=339#map_section
# https://giftpass.sodexomerchant.com/getMap?id=331#map_section
# https://giftpass.sodexomerchant.com/getMap?id=329#map_section
# https://giftpass.sodexomerchant.com/getMap?id=327#map_section
# https://giftpass.sodexomerchant.com/getMap?id=326#map_section
# https://giftpass.sodexomerchant.com/getMap?id=324#map_section
# https://giftpass.sodexomerchant.com/getMap?id=323#map_section
# https://giftpass.sodexomerchant.com/getMap?id=317#map_section
# https://giftpass.sodexomerchant.com/getMap?id=307#map_section
# https://giftpass.sodexomerchant.com/getMap?id=306#map_section
# https://giftpass.sodexomerchant.com/getMap?id=300#map_section
# https://giftpass.sodexomerchant.com/getMap?id=285#map_section
# https://giftpass.sodexomerchant.com/getMap?id=284#map_section
# https://giftpass.sodexomerchant.com/getMap?id=280#map_section
# https://giftpass.sodexomerchant.com/getMap?id=277#map_section
# https://giftpass.sodexomerchant.com/getMap?id=275#map_section
# https://giftpass.sodexomerchant.com/getMap?id=272#map_section
# https://giftpass.sodexomerchant.com/getMap?id=260#map_section
# https://giftpass.sodexomerchant.com/getMap?id=257#map_section
# https://giftpass.sodexomerchant.com/getMap?id=252#map_section
# https://giftpass.sodexomerchant.com/getMap?id=244#map_section
# https://giftpass.sodexomerchant.com/getMap?id=209#map_section
# https://giftpass.sodexomerchant.com/getMap?id=197#map_section
# https://giftpass.sodexomerchant.com/getMap?id=193#map_section
# https://giftpass.sodexomerchant.com/getMap?id=189#map_section
# https://giftpass.sodexomerchant.com/getMap?id=187#map_section
# https://giftpass.sodexomerchant.com/getMap?id=183#map_section
# https://giftpass.sodexomerchant.com/getMap?id=175#map_section
# https://giftpass.sodexomerchant.com/getMap?id=173#map_section
# https://giftpass.sodexomerchant.com/getMap?id=71#map_section
# https://giftpass.sodexomerchant.com/getMap?id=70#map_section
# https://giftpass.sodexomerchant.com/getMap?id=58#map_section
# https://giftpass.sodexomerchant.com/getMap?id=49#map_section
# https://giftpass.sodexomerchant.com/getMap?id=51#map_section
# https://giftpass.sodexomerchant.com/getMap?id=45#map_section
# https://giftpass.sodexomerchant.com/getMap?id=47#map_section
# https://giftpass.sodexomerchant.com/getMap?id=48#map_section
# https://giftpass.sodexomerchant.com/getMap?id=43#map_section
# https://giftpass.sodexomerchant.com/getMap?id=44#map_section
# https://giftpass.sodexomerchant.com/getMap?id=31#map_section
# https://giftpass.sodexomerchant.com/getMap?id=37#map_section
# https://giftpass.sodexomerchant.com/getMap?id=25#map_section
# https://giftpass.sodexomerchant.com/getMap?id=24#map_section
# https://giftpass.sodexomerchant.com/getMap?id=19#map_section
# https://giftpass.sodexomerchant.com/getMap?id=20#map_section
# https://giftpass.sodexomerchant.com/getMap?id=11#map_section
# https://giftpass.sodexomerchant.com/getMap?id=15#map_section
# https://giftpass.sodexomerchant.com/getMap?id=16#map_section
# https://giftpass.sodexomerchant.com/getMap?id=4#map_section
# https://giftpass.sodexomerchant.com/getMap?id=8#map_section
# https://giftpass.sodexomerchant.com/getMap?id=502#map_section
# https://giftpass.sodexomerchant.com/getMap?id=82#map_section
# https://giftpass.sodexomerchant.com/getMap?id=165#map_section
# https://giftpass.sodexomerchant.com/getMap?id=404#map_section
# https://giftpass.sodexomerchant.com/getMap?id=668#map_section
# https://giftpass.sodexomerchant.com/getMap?id=498#map_section
# https://giftpass.sodexomerchant.com/getMap?id=85#map_section
# https://giftpass.sodexomerchant.com/getMap?id=136#map_section
# https://giftpass.sodexomerchant.com/getMap?id=915#map_section
# https://giftpass.sodexomerchant.com/getMap?id=883#map_section
# https://giftpass.sodexomerchant.com/getMap?id=812#map_section
# https://giftpass.sodexomerchant.com/getMap?id=598#map_section
# https://giftpass.sodexomerchant.com/getMap?id=595#map_section
# https://giftpass.sodexomerchant.com/getMap?id=583#map_section
# https://giftpass.sodexomerchant.com/getMap?id=578#map_section
# https://giftpass.sodexomerchant.com/getMap?id=561#map_section
# https://giftpass.sodexomerchant.com/getMap?id=560#map_section
# https://giftpass.sodexomerchant.com/getMap?id=559#map_section
# https://giftpass.sodexomerchant.com/getMap?id=546#map_section
# https://giftpass.sodexomerchant.com/getMap?id=545#map_section
# https://giftpass.sodexomerchant.com/getMap?id=544#map_section
# https://giftpass.sodexomerchant.com/getMap?id=543#map_section
# https://giftpass.sodexomerchant.com/getMap?id=500#map_section
# https://giftpass.sodexomerchant.com/getMap?id=486#map_section
# https://giftpass.sodexomerchant.com/getMap?id=475#map_section
# https://giftpass.sodexomerchant.com/getMap?id=474#map_section
# https://giftpass.sodexomerchant.com/getMap?id=469#map_section
# https://giftpass.sodexomerchant.com/getMap?id=463#map_section
# https://giftpass.sodexomerchant.com/getMap?id=421#map_section
# https://giftpass.sodexomerchant.com/getMap?id=335#map_section
# https://giftpass.sodexomerchant.com/getMap?id=302#map_section
# https://giftpass.sodexomerchant.com/getMap?id=170#map_section
# https://giftpass.sodexomerchant.com/getMap?id=164#map_section
# https://giftpass.sodexomerchant.com/getMap?id=91#map_section
# https://giftpass.sodexomerchant.com/getMap?id=92#map_section
# https://giftpass.sodexomerchant.com/getMap?id=87#map_section
# https://giftpass.sodexomerchant.com/getMap?id=88#map_section
# https://giftpass.sodexomerchant.com/getMap?id=86#map_section
# https://giftpass.sodexomerchant.com/getMap?id=81#map_section
# https://giftpass.sodexomerchant.com/getMap?id=78#map_section
# https://giftpass.sodexomerchant.com/getMap?id=524#map_section
# https://giftpass.sodexomerchant.com/getMap?id=803#map_section
# https://giftpass.sodexomerchant.com/getMap?id=802#map_section
# https://giftpass.sodexomerchant.com/getMap?id=787#map_section
# https://giftpass.sodexomerchant.com/getMap?id=753#map_section
# https://giftpass.sodexomerchant.com/getMap?id=631#map_section
# https://giftpass.sodexomerchant.com/getMap?id=452#map_section
# https://giftpass.sodexomerchant.com/getMap?id=313#map_section
# https://giftpass.sodexomerchant.com/getMap?id=262#map_section
# https://giftpass.sodexomerchant.com/getMap?id=140#map_section
# https://giftpass.sodexomerchant.com/getMap?id=141#map_section
# https://giftpass.sodexomerchant.com/getMap?id=142#map_section
# https://giftpass.sodexomerchant.com/getMap?id=923#map_section
# https://giftpass.sodexomerchant.com/getMap?id=826#map_section
# https://giftpass.sodexomerchant.com/getMap?id=825#map_section
# https://giftpass.sodexomerchant.com/getMap?id=805#map_section
# https://giftpass.sodexomerchant.com/getMap?id=804#map_section
# https://giftpass.sodexomerchant.com/getMap?id=792#map_section
# https://giftpass.sodexomerchant.com/getMap?id=791#map_section
# https://giftpass.sodexomerchant.com/getMap?id=790#map_section
# https://giftpass.sodexomerchant.com/getMap?id=789#map_section
# https://giftpass.sodexomerchant.com/getMap?id=788#map_section
# https://giftpass.sodexomerchant.com/getMap?id=785#map_section
# https://giftpass.sodexomerchant.com/getMap?id=784#map_section
# https://giftpass.sodexomerchant.com/getMap?id=735#map_section
# https://giftpass.sodexomerchant.com/getMap?id=719#map_section
# https://giftpass.sodexomerchant.com/getMap?id=597#map_section
# https://giftpass.sodexomerchant.com/getMap?id=592#map_section
# https://giftpass.sodexomerchant.com/getMap?id=586#map_section
# https://giftpass.sodexomerchant.com/getMap?id=571#map_section
# https://giftpass.sodexomerchant.com/getMap?id=570#map_section
# https://giftpass.sodexomerchant.com/getMap?id=554#map_section
# https://giftpass.sodexomerchant.com/getMap?id=541#map_section
# https://giftpass.sodexomerchant.com/getMap?id=525#map_section
# https://giftpass.sodexomerchant.com/getMap?id=504#map_section
# https://giftpass.sodexomerchant.com/getMap?id=420#map_section
# https://giftpass.sodexomerchant.com/getMap?id=412#map_section
# https://giftpass.sodexomerchant.com/getMap?id=394#map_section
# https://giftpass.sodexomerchant.com/getMap?id=379#map_section
# https://giftpass.sodexomerchant.com/getMap?id=338#map_section
# https://giftpass.sodexomerchant.com/getMap?id=321#map_section
# https://giftpass.sodexomerchant.com/getMap?id=319#map_section
# https://giftpass.sodexomerchant.com/getMap?id=294#map_section
# https://giftpass.sodexomerchant.com/getMap?id=287#map_section
# https://giftpass.sodexomerchant.com/getMap?id=251#map_section
# https://giftpass.sodexomerchant.com/getMap?id=181#map_section
# https://giftpass.sodexomerchant.com/getMap?id=149#map_section
# https://giftpass.sodexomerchant.com/getMap?id=150#map_section
# https://giftpass.sodexomerchant.com/getMap?id=135#map_section
# https://giftpass.sodexomerchant.com/getMap?id=104#map_section
# https://giftpass.sodexomerchant.com/getMap?id=105#map_section
# https://giftpass.sodexomerchant.com/getMap?id=96#map_section
# https://giftpass.sodexomerchant.com/getMap?id=99#map_section
# https://giftpass.sodexomerchant.com/getMap?id=100#map_section
# https://giftpass.sodexomerchant.com/getMap?id=102#map_section
# https://giftpass.sodexomerchant.com/getMap?id=103#map_section
# https://giftpass.sodexomerchant.com/getMap?id=95#map_section
# https://giftpass.sodexomerchant.com/getMap?id=935#map_section
# https://giftpass.sodexomerchant.com/getMap?id=762#map_section
# https://giftpass.sodexomerchant.com/getMap?id=739#map_section
# https://giftpass.sodexomerchant.com/getMap?id=734#map_section
# https://giftpass.sodexomerchant.com/getMap?id=730#map_section
# https://giftpass.sodexomerchant.com/getMap?id=711#map_section
# https://giftpass.sodexomerchant.com/getMap?id=510#map_section
# https://giftpass.sodexomerchant.com/getMap?id=501#map_section
# https://giftpass.sodexomerchant.com/getMap?id=320#map_section
# https://giftpass.sodexomerchant.com/getMap?id=120#map_section
# https://giftpass.sodexomerchant.com/getMap?id=122#map_section
# https://giftpass.sodexomerchant.com/getMap?id=117#map_section
# https://giftpass.sodexomerchant.com/getMap?id=119#map_section
# https://giftpass.sodexomerchant.com/getMap?id=958#map_section
# https://giftpass.sodexomerchant.com/getMap?id=929#map_section
# https://giftpass.sodexomerchant.com/getMap?id=918#map_section
# https://giftpass.sodexomerchant.com/getMap?id=894#map_section
# https://giftpass.sodexomerchant.com/getMap?id=811#map_section
# https://giftpass.sodexomerchant.com/getMap?id=750#map_section
# https://giftpass.sodexomerchant.com/getMap?id=744#map_section
# https://giftpass.sodexomerchant.com/getMap?id=638#map_section
# https://giftpass.sodexomerchant.com/getMap?id=627#map_section
# https://giftpass.sodexomerchant.com/getMap?id=573#map_section
# https://giftpass.sodexomerchant.com/getMap?id=333#map_section
# https://giftpass.sodexomerchant.com/getMap?id=330#map_section
# https://giftpass.sodexomerchant.com/getMap?id=192#map_section
# https://giftpass.sodexomerchant.com/getMap?id=162#map_section
# https://giftpass.sodexomerchant.com/getMap?id=148#map_section
# https://giftpass.sodexomerchant.com/getMap?id=145#map_section
# https://giftpass.sodexomerchant.com/getMap?id=134#map_section
# https://giftpass.sodexomerchant.com/getMap?id=108#map_section
# https://giftpass.sodexomerchant.com/getMap?id=79#map_section
# https://giftpass.sodexomerchant.com/getMap?id=743#map_section
# https://giftpass.sodexomerchant.com/getMap?id=654#map_section
# https://giftpass.sodexomerchant.com/getMap?id=912#map_section
# https://giftpass.sodexomerchant.com/getMap?id=720#map_section
# https://giftpass.sodexomerchant.com/getMap?id=491#map_section
# https://giftpass.sodexomerchant.com/getMap?id=470#map_section
# https://giftpass.sodexomerchant.com/getMap?id=441#map_section
# https://giftpass.sodexomerchant.com/getMap?id=176#map_section
# https://giftpass.sodexomerchant.com/getMap?id=144#map_section
# https://giftpass.sodexomerchant.com/getMap?id=77#map_section
# https://giftpass.sodexomerchant.com/getMap?id=453#map_section
# https://giftpass.sodexomerchant.com/getMap?id=953#map_section
# https://giftpass.sodexomerchant.com/getMap?id=952#map_section
# https://giftpass.sodexomerchant.com/getMap?id=928#map_section
# https://giftpass.sodexomerchant.com/getMap?id=927#map_section
# https://giftpass.sodexomerchant.com/getMap?id=919#map_section
# https://giftpass.sodexomerchant.com/getMap?id=907#map_section
# https://giftpass.sodexomerchant.com/getMap?id=738#map_section
# https://giftpass.sodexomerchant.com/getMap?id=466#map_section
# https://giftpass.sodexomerchant.com/getMap?id=451#map_section
# https://giftpass.sodexomerchant.com/getMap?id=93#map_section
# http://www.sodexoindonesia.co.id/
# https://www.sodexo.co.id/perhatian-hukum/
# https://giftpass.sodexomerchant.com/page/contact
# mailto:cs.svc.id@sodexo.com
# http://www.sodexo.com/

# %%
container = content.find_elements_by_xpath('/html/body/section/div[1]/div[1]')
print(container)
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="1b98e882-2a7c-9247-b534-43f242a49b52", element="8a59ba2d-d94b-ea4a-a638-930679421b87")>]

# %%
import json
list_link = []
merchant_per_category = []

for i in range(10):
    i = i + 1 
    print(i)
    xpath = '/html/body/section/div[1]/div'
    bracket1 = '['
    str_i = str(i)
    bracket2 = ']'
    xpath_container = xpath+bracket1+str_i+bracket2
    container = content.find_elements_by_xpath(xpath_container)
    container_0 = container[0]
    header3 = container_0.find_element_by_tag_name('h3')
    category = header3.text
#     print(category)
    list_a = container_0.find_elements_by_xpath('//a[@href]')
    for cont in list_a:
        hr = container_0.find_element_by_tag_name('<hr>')
        if hr == '' :
            href = cont.get_attribute('href')
        else:
            break
#         print(href)
        list_link.append(href)
    merchant_per_category.append([category,list_link])
# Out:
# 1
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-34-ded7af929b73> in <module>
#      18     list_a = container_0.find_elements_by_xpath('//a[@href]')
#      19     for cont in list_a:
# ---> 20         hr = container_0.find_element_by_tag_name('<hr>')
#      21         if hr == '' :
#      22             href = cont.get_attribute('href')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     303             element = element.find_element_by_tag_name('h1')
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#     307     def find_elements_by_tag_name(self, name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     657
#     658         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 659                              {"using": by, "value": value})['value']
#     660
#     661     def find_elements(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# InvalidSelectorException: Message: Given css selector expression "<hr>" is invalid: InvalidSelectorError: Element.querySelector: '<hr>' is not a valid selector: "<hr>"

# %%
merchant_per_category[1]
# Out:
# ['Supermarket', []]

# %%
container = content.find_elements_by_xpath('/html/body/section/div[1]/div[2]')
print(container)
container[0]
# Out:
# [<selenium.webdriver.firefox.webelement.FirefoxWebElement (session="1b98e882-2a7c-9247-b534-43f242a49b52", element="d03c6389-7c3b-854d-888e-d7f0139232bd")>]
# <selenium.webdriver.firefox.webelement.FirefoxWebElement (session="1b98e882-2a7c-9247-b534-43f242a49b52", element="d03c6389-7c3b-854d-888e-d7f0139232bd")>

# %%
hr = container_0.find_element_by_tag_name('hr')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-31-c4d41be1f1bf> in <module>
# ----> 1 hr = container_0.find_element_by_tag_name('hr')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_tag_name(self, name)
#     303             element = element.find_element_by_tag_name('h1')
#     304         """
# --> 305         return self.find_element(by=By.TAG_NAME, value=name)
#     306
#     307     def find_elements_by_tag_name(self, name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     657
#     658         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 659                              {"using": by, "value": value})['value']
#     660
#     661     def find_elements(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: Unable to locate element: hr
